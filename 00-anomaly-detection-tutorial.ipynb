# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# ##  Azure ML and IoT Edge Workshop
#
# For more information go to https://aka.ms/aml-tutorial/ai-iot-power-couple

# %% [markdown]
# ## 1: Specify parameters
# Fill in the parameters below.  If you already have IoT Hub or Azure ML workspace, then enter their information here. Otherwise, the parameter names will be used in provisioning new services.

# %%
#####################################
# Enter the resource group in Azure where you want to provision the resources 
resource_group_name = "edge-iot-workshop"
######################################

#####################################
# Enter Azure region where your services will be provisioned
azure_region="West US"
#####################################

# Pick an Azure IoT Hub name
iot_hub_name="megan-iothub"

# Pick a name for your IoT Edge device
# This is NOT the name of your VM, but it's just an entry in your IoT Hub, so you can pick any name
iot_device_id="iot-edge-device"

#####################################
# Pick a subscription ID to provision your services
subscription_id = "bfd64d4e-102f-41ba-8403-9218afd63f63"
#####################################

# Pick a name for your Azure ML workspace
aml_workspace_name = "megan-aml-iotedge"

#####################################
# Enter the name of the IoT Edge device VM name you created
iot_edge_device_name = "iot-workshop"
#####################################

# %%
# DO NOT CHANGE THIS VALUE for this tutorial
# This is the name of the AML module you deploy to the device
module_name = "machinelearningmodule"

# %%
# !az login
# Out:
#   File "<ipython-input-4-9d6fc067d6a0>", line 1
#     az login
#            ^
# SyntaxError: invalid syntax

# %%
# !az account set --subscription $subscription_id

# %%
# !az extension add --name azure-cli-iot-ext
# Out:
#  - Installing ...

# %%
# Check core SDK version number
import azureml.core
from azureml.core import Workspace

print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.0.33

# %% [markdown]
# ## 2: Provision Azure ML Workspace and IoT Hub
# If you already have provisioned these resources, then skip this section and go Section 3.

# %% [markdown]
# ### 2.1: Provision Azure ML workspace
# After you've done this once you no longer have to run this cell anymore

# %%
ws = Workspace.create(subscription_id = subscription_id,
                resource_group = resource_group_name,
                name = aml_workspace_name,
                location = azure_region)

ws.write_config()
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.
# UserWarning: The resource group doesn't exist or was not provided. AzureML SDK is creating a resource group=tedway-iotedge-workshop-1 in location=eastus2 using subscription=75f78a03-482f-4fd8-8c71-5ddc08f92726.
# Deploying KeyVault with name tedwayamkeyvault2c650163.
# Deploying StorageAccount with name tedwayamstorage6880bba56.
# Deploying AppInsights with name tedwayaminsights906e665a.
# Deployed AppInsights with name tedwayaminsights906e665a.
# Deployed KeyVault with name tedwayamkeyvault2c650163.
# Deployed StorageAccount with name tedwayamstorage6880bba56.
# Deploying Workspace with name tedway-aml-iotedge.
# Deployed Workspace with name tedway-aml-iotedge.

# %% [markdown]
# ### 2.2: Provision IoT Hub
# If you get an error because there's already one free hub in your subscription, change the SKU to S1. If you get an error that the IoT Hub name isn't available, it means that someone else already has a hub with that name.

# %%
# !az iot hub create --resource-group $resource_group_name --name $iot_hub_name --sku S1
# Out:
# {- Finished ..
#   "etag": "AAAAAAXxBCk=",
#   "id": "/subscriptions/75f78a03-482f-4fd8-8c71-5ddc08f92726/resourceGroups/tedway-iotedge-workshop-1/providers/Microsoft.Devices/IotHubs/tedway-iothub1",
#   "location": "eastus2",
#   "name": "tedway-iothub1",
#   "properties": {
#     "authorizationPolicies": null,
#     "cloudToDevice": {
#       "defaultTtlAsIso8601": "1:00:00",
#       "feedback": {
#         "lockDurationAsIso8601": "0:01:00",
#         "maxDeliveryCount": 10,
#         "ttlAsIso8601": "1:00:00"
#       },
#       "maxDeliveryCount": 10
#     },
#     "comments": null,
#     "deviceStreams": null,
#     "enableFileUploadNotifications": false,
#     "eventHubEndpoints": {
#       "events": {
#         "endpoint": "sb://iothub-ns-tedway-iot-1663768-896ab113d4.servicebus.windows.net/",
#         "partitionCount": 2,
#         "partitionIds": [
#           "0",
#           "1"
#         ],
#         "path": "tedway-iothub1",
#         "retentionTimeInDays": 1
#       },
#       "operationsMonitoringEvents": {
#         "endpoint": "sb://iothub-ns-tedway-iot-1663768-896ab113d4.servicebus.windows.net/",
#         "partitionCount": 2,
#         "partitionIds": [
#           "0",
#           "1"
#         ],
#         "path": "tedway-iothub1-operationmonitoring",
#         "retentionTimeInDays": 1
#       }
#     },
#     "features": "None",
#     "hostName": "tedway-iothub1.azure-devices.net",
#     "ipFilterRules": [],
#     "locations": [
#       {
#         "location": "East US 2",
#         "role": "primary"
#       },
#       {
#         "location": "Central US",
#         "role": "secondary"
#       }
#     ],
#     "messagingEndpoints": {
#       "fileNotifications": {
#         "lockDurationAsIso8601": "0:01:00",
#         "maxDeliveryCount": 10,
#         "ttlAsIso8601": "1:00:00"
#       }
#     },
#     "operationsMonitoringProperties": {
#       "events": {
#         "C2DCommands": "None",
#         "Connections": "None",
#         "DeviceIdentityOperations": "None",
#         "DeviceTelemetry": "None",
#         "FileUploadOperations": "None",
#         "None": "None",
#         "Routes": "None"
#       }
#     },
#     "provisioningState": "Succeeded",
#     "routing": {
#       "endpoints": {
#         "eventHubs": [],
#         "serviceBusQueues": [],
#         "serviceBusTopics": [],
#         "storageContainers": []
#       },
#       "fallbackRoute": {
#         "condition": "true",
#         "endpointNames": [
#           "events"
#         ],
#         "isEnabled": true,
#         "name": "$fallback"
#       },
#       "routes": []
#     },
#     "state": "Active",
#     "storageEndpoints": {
#       "$default": {
#         "connectionString": "",
#         "containerName": "",
#         "sasTtlAsIso8601": "1:00:00"
#       }
#     }
#   },
#   "resourcegroup": "tedway-iotedge-workshop-1",
#   "sku": {
#     "capacity": 1,
#     "name": "S1",
#     "tier": "Standard"
#   },
#   "subscriptionid": "75f78a03-482f-4fd8-8c71-5ddc08f92726",
#   "tags": {},
#   "type": "Microsoft.Devices/IotHubs"
# }

# %%
# Register an IoT Edge device (create a new entry in the Iot Hub)
# !az iot hub device-identity create --hub-name $iot_hub_name --device-id $iot_device_id --edge-enabled
# Out:
# {
#   "authentication": {
#     "symmetricKey": {
#       "primaryKey": "YOsdlSTyWyXNQN7hx6a4mSlOJhLU3PhN1ZyPs7WEdCU=",
#       "secondaryKey": "CtD0oKFGqchlYeNLoylKM+97TncIZczH6x3kDhTJIwM="
#     },
#     "type": "sas",
#     "x509Thumbprint": {
#       "primaryThumbprint": null,
#       "secondaryThumbprint": null
#     }
#   },
#   "capabilities": {
#     "iotEdge": true
#   },
#   "cloudToDeviceMessageCount": 0,
#   "connectionState": "Disconnected",
#   "connectionStateUpdatedTime": "0001-01-01T00:00:00",
#   "deviceId": "iot-edge-device",
#   "deviceScope": "ms-azure-iot-edge://iot-edge-device-636939589257908142",
#   "etag": "NjQ4MTI1NzU=",
#   "generationId": "636939589257908142",
#   "lastActivityTime": "0001-01-01T00:00:00",
#   "status": "enabled",
#   "statusReason": null,
#   "statusUpdatedTime": "0001-01-01T00:00:00"
# }

# %% [markdown]
# ## 3: Load resources
# Load the Azure ML workspace and get the IoT Edge device connection string in your IoT Hub.

# %% [markdown]
# ### 3.1 Load the Azure ML workspace.

# %%
# Initialize a workspace object from persisted configuration
from azureml.core import Workspace

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# tedway-aml-iotedge
# tedway-iotedge-workshop-1
# eastus2
# 75f78a03-482f-4fd8-8c71-5ddc08f92726

# %% [markdown]
# ### 3.2: Get the Azure IoT Edge device connection string
# Keep this connection string handy for configuring your IoT Edge device!

# %%
# Get the connection string that you will need to enter in the IoT Edge device
# !az iot hub device-identity show-connection-string --device-id $iot_device_id --hub-name $iot_hub_name
# Out:
# {
#   "connectionString": "HostName=tedway-iothub1.azure-devices.net;DeviceId=iot-edge-device;SharedAccessKey=YOsdlSTyWyXNQN7hx6a4mSlOJhLU3PhN1ZyPs7WEdCU="
# }

# %% [markdown]
# ### 3.4 Enter the connection string into your IoT Edge device
# Copy and paste the connection string from above into the command below

# %%
# !az vm run-command invoke -g $resource_group_name -n $iot_edge_device_name --command-id RunShellScript --script "/etc/iotedge/configedge.sh 'HostName=tedway-iothub1.azure-devices.net;DeviceId=iot-edge-device;SharedAccessKey=YOsdlSTyWyXNQN7hx6a4mSlOJhLU3PhN1ZyPs7WEdCU='"
# Out:
# {- Finished ..
#   "value": [
#     {
#       "code": "ProvisioningState/succeeded",
#       "displayStatus": "Provisioning succeeded",
#       "level": "Info",
#       "message": "Enable succeeded: \n[stdout]\n Mon May 20 14:36:13 UTC 2019 Connection string set to HostName=tedway-iothub1.azure-devices.net;DeviceId=iot-edge-device;SharedAccessKey=YOsdlSTyWyXNQN7hx6a4mSlOJhLU3PhN1ZyPs7WEdCU=\n\n[stderr]\n",
#       "time": null
#     }
#   ]
# }

# %% [markdown]
# ## 3: Anomaly Detection Model

# %% [markdown]
# ## 3.1 Train the model

# %%
# !pip install pandas
# !pip install sklearn
# Out:
# Requirement already satisfied: pandas in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (0.23.4)
# Requirement already satisfied: pytz>=2011k in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas) (1.16.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas) (2.7.5)
# Requirement already satisfied: six>=1.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas) (1.11.0)
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: sklearn in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from sklearn) (0.20.3)
# Requirement already satisfied: numpy>=1.8.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.16.2)
# Requirement already satisfied: scipy>=0.13.3 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.1.0)
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Load the data set
import pandas
import numpy
import pickle


from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
temp_data = pandas.read_csv('temperature_data.csv')
temp_data
# Out:
#      machine_temperature  machine_pressure  ambient_temperature  \
# 0              21.018765          1.002138            20.768628
# 1              21.965850          1.110034            21.223653
# 2              22.999720          1.227816            20.872120
# 3              23.731603          1.311195            21.470454
# 4              24.902941          1.444639            20.895378
# 5              24.736582          1.425687            20.947997
# 6              25.586945          1.522563            21.445649
# 7              26.088789          1.579736            21.196497
# 8              26.541049          1.631259            20.985543
# 9              27.439798          1.733648            20.509265
# 10             28.456884          1.849518            21.002556
# 11             28.870965          1.896692            20.606887
# 12             28.787264          1.887157            20.681630
# 13             29.050185          1.917110            20.540689
# 14             29.710265          1.992309            21.372221
# 15             30.696087          2.104618            20.569975
# 16             30.486279          2.080715            21.130830
# 17             31.022556          2.141810            21.126828
# 18             31.164690          2.158003            21.177947
# 19             31.578444          2.205139            20.829884
# 20             32.178819          2.273536            20.590081
# 21             33.356748          2.407731            21.309864
# 22             33.218909          2.392028            21.004838
# 23             33.131139          2.382029            21.444895
# 24             33.408599          2.413638            20.891628
# 25             33.669956          2.443413            21.394510
# 26             34.342841          2.520070            21.144291
# 27             34.421092          2.528985            21.239038
# 28             35.047850          2.600388            20.820539
# 29             36.177472          2.729079            20.681298
# ..                   ...               ...                  ...
# 588           102.813176         10.320488            20.956312
# 589           102.483170         10.282893            20.507582
# 590           102.365824         10.269524            20.909385
# 591           102.501005         10.284925            20.808534
# 592           102.803850         10.319426            20.645756
# 593           102.722283         10.310134            20.810427
# 594           103.083454         10.351280            21.256180
# 595           103.252579         10.370547            21.127109
# 596           103.630516         10.413603            21.213299
# 597           103.860791         10.439837            20.753988
# 598           103.974645         10.452808            21.440397
# 599           104.448887         10.506835            20.621772
# 600           104.661369         10.531042            21.454543
# 601           104.532926         10.516409            21.265045
# 602           104.668951         10.531906            21.493707
# 603           105.163504         10.588247            20.970917
# 604           105.545793         10.631799            20.620300
# 605           105.591495         10.637006            21.457043
# 606           105.840109         10.665329            20.829258
# 607           106.298019         10.717496            20.792057
# 608           106.744870         10.768403            21.152379
# 609           106.376427         10.726428            20.521326
# 610           106.392990         10.728315            21.328603
# 611           105.916648         10.674049            21.205952
# 612           105.935861         10.676237            20.989614
# 613           105.877218         10.669556            20.533100
# 614           105.990477         10.682459            21.383384
# 615           105.642759         10.642846            21.347985
# 616           105.742701         10.654232            20.568153
# 617           105.532546         10.630290            20.725628
#
#      ambient_humidity  anomaly
# 0                  24        0
# 1                  26        0
# 2                  25        0
# 3                  25        0
# 4                  24        0
# 5                  26        0
# 6                  25        0
# 7                  26        0
# 8                  25        0
# 9                  25        0
# 10                 24        0
# 11                 24        0
# 12                 25        0
# 13                 24        0
# 14                 24        0
# 15                 24        0
# 16                 24        0
# 17                 25        0
# 18                 25        0
# 19                 24        0
# 20                 25        0
# 21                 25        0
# 22                 24        0
# 23                 24        0
# 24                 26        0
# 25                 26        1
# 26                 25        0
# 27                 25        0
# 28                 26        0
# 29                 25        0
# ..                ...      ...
# 588                25        0
# 589                25        0
# 590                25        0
# 591                25        0
# 592                26        0
# 593                24        0
# 594                25        1
# 595                25        1
# 596                25        1
# 597                25        1
# 598                24        1
# 599                26        1
# 600                25        1
# 601                24        1
# 602                26        1
# 603                25        1
# 604                26        1
# 605                26        1
# 606                26        1
# 607                24        1
# 608                24        1
# 609                25        1
# 610                24        1
# 611                25        1
# 612                26        1
# 613                25        1
# 614                24        1
# 615                24        1
# 616                26        1
# 617                26        1
#
# [618 rows x 5 columns]

# %%
# Load features and labels
X, Y = temp_data[['machine_temperature', 'machine_pressure', 'ambient_temperature', 'ambient_humidity']].values, temp_data['anomaly'].values

# %%
# Split data 65%-35% into training set and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.35, random_state=0)

# Change regularization rate and you will likely get a different accuracy.
reg = 0.01

# Train a decision tree on the training set
#clf1 = LogisticRegression(C=1/reg).fit(X_train, Y_train)
clf1 = tree.DecisionTreeClassifier()
clf1 = clf1.fit(X_train, Y_train)
print (clf1)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Evaluate the test set
accuracy = clf1.score(X_test, Y_test)

print ("Accuracy is {}".format(accuracy))
# Out:
# Accuracy is 0.9861751152073732

# %%
# Serialize the model and write to disk
f = open('model.pkl', 'wb')
pickle.dump(clf1, f)
f.close()
print ("Exported the model to model.pkl")
# Out:
# Exported the model to model.pkl

# %%
# Test the model by importing it and providing a sample data point
print("Import the model from model.pkl")
f2 = open('model.pkl', 'rb')
clf2 = pickle.load(f2)

# Normal (not an anomaly)
#X_new = [[24.90294136, 1.44463889, 20.89537849, 24]]
#X_new = [[33.40859853, 2.413637808, 20.89162813, 26]]
#X_new = [[34.42109181, 2.528985143, 21.23903786, 25]]

# Anomaly
X_new = [[33.66995566, 2.44341267, 21.39450979, 26]]
#X_new = [[105.5457931, 10.63179922, 20.62029994, 26]]

print ('New sample: {}'.format(X_new))

pred = clf2.predict(X_new)
print('Predicted class is {}'.format(pred))
# Out:
# Import the model from model.pkl
# New sample: [[33.66995566, 2.44341267, 21.39450979, 26]]
# Predicted class is [1]

# %% [markdown]
# ### 3.2 Register Model

# %% [markdown]
# You can add tags and descriptions to your models. Note you need to have a `model.pkl` file in the current directory. The below call registers that file as a model with the same name `model.pkl` in the workspace.
#
# Using tags, you can track useful information such as the name and version of the machine learning library used to train the model. Note that tags must be alphanumeric.

# %%
from azureml.core.model import Model

model = Model.register(model_path = "model.pkl",
                       model_name = "model.pkl",
                       tags = {'area': "anomaly", 'type': "classification"},
                       description = "Sample anomaly detection model for IOT tutorial",
                       workspace = ws)
# Out:
# Registering model model.pkl

# %%
print(model.name, model.description, model.version, sep = '\t')
# Out:
# model.pkl	Sample anomaly detection model for IOT tutorial	1

# %% [markdown]
# ### 3.2 Create Docker Image

# %% [markdown]
# Create the driver file.  Note that the `model.pkl` file in the get_model_path call is referring to a model named `model.pkl` registered under the workspace (what you registered above). It is NOT referenceing the local file.

# %%
# %%writefile iot_score.py
# This script generates the scoring file
# with the init and run functions needed to 
# operationalize the anomaly detection sample

import pickle
import json
import pandas
from sklearn.externals import joblib
from sklearn.linear_model import Ridge
from azureml.core.model import Model

def init():
    global model
    # this is a different behavior than before when the code is run locally, even though the code is the same.
    model_path = Model.get_model_path('model.pkl')
    # deserialize the model file back into a sklearn model
    model = joblib.load(model_path)

# note you can pass in multiple rows for scoring
def run(input_str):
    try:
        input_json = json.loads(input_str)
        input_df = pandas.DataFrame([[input_json['machine']['temperature'],input_json['machine']['pressure'],input_json['ambient']['temperature'],input_json['ambient']['humidity']]])
        pred = model.predict(input_df)
        print("Prediction is ", pred[0])
    except Exception as e:
        result = str(e)
        
    if pred[0] == 1:
        input_json['anomaly']=True
    else:
        input_json['anomaly']=False
        
    return [json.dumps(input_json)]
# Out:
# Overwriting iot_score.py

# %%
# This specifies the dependencies to include in the environment
from azureml.core.conda_dependencies import CondaDependencies 

myenv = CondaDependencies.create(conda_packages=['pandas', 'scikit-learn', 'numpy'])

with open("myenv.yml","w") as f:
    f.write(myenv.serialize_to_string())

# %% [markdown]
# You can add tags and descriptions to images. Also, an image can contain multiple models.

# %%
from azureml.core.image import Image, ContainerImage

image_config = ContainerImage.image_configuration(runtime= "python",
                                 execution_script="iot_score.py",
                                 conda_file="myenv.yml",
                                 tags = {'area': "iot", 'type': "classification"},
                                 description = "IOT Edge anomaly detection demo")


image = Image.create(name = "tempanomalydetection",
                     # this is the model object 
                     models = [model],
                     image_config = image_config, 
                     workspace = ws)
# Out:
# Creating image

# %% [markdown]
# Note that following command can take few minutes.

# %%
image.wait_for_creation(show_output = True)
# Out:
# Running.................................................
# SucceededImage creation operation finished for image tempanomalydetection:1, operation "Succeeded"

# %% [markdown]
# List images by tag and find out the detailed build log for debugging.

# %%
for i in Image.list(workspace = ws,tags = ["area"]):
    print('{}(v.{} [{}]) stored at {} with build log {}'.format(i.name, i.version, i.creation_state, i.image_location, i.image_build_log_uri))
# Out:
# tempanomalydetection(v.1 [Succeeded]) stored at tedwayamliot70d2b646.azurecr.io/tempanomalydetection:1 with build log https://tedwayamstorage6880bba56.blob.core.windows.net/azureml/ImageLogs/44fc880b-01c8-40ac-af9c-5dcfa0148044/build.log?sv=2018-03-28&sr=b&sig=WfUqmtr0CKhVMyAyY6FHkcQTKqbVL11IXX5F0WT7fss%3D&st=2019-05-20T14%3A37%3A20Z&se=2019-06-19T14%3A42%3A20Z&sp=rl

# %% [markdown]
# ## 4: Test model on Azure Container Instance
# You can test the performance of your model by deploying the container to ACI.  Note that the service creation can take few minutes.

# %%
from azureml.core.webservice import AciWebservice

aciconfig = AciWebservice.deploy_configuration(cpu_cores = 1, 
                                               memory_gb = 1, 
                                               tags = {'area': "iot", 'type': "classification"}, 
                                               description = 'IOT Edge anomaly detection demo')

# %%
from azureml.core.webservice import Webservice

aci_service_name = 'tempsensor-iotedge-ml-6'
print(aci_service_name)
aci_service = Webservice.deploy_from_image(deployment_config = aciconfig,
                                           image = image,
                                           name = aci_service_name,
                                           workspace = ws)
aci_service.wait_for_deployment(True)
print(aci_service.state)
# Out:
# tempsensor-iotedge-ml-6
# Creating service
# Running.......................
# SucceededACI service creation operation finished, operation "Succeeded"
# Healthy

# %% [markdown]
# ### 4.1: Test web service

# %% [markdown]
# Call the web service with some dummy input data to get a prediction.

# %%
import json

# Anomaly
#test_sample = json.dumps({ "machine": { "temperature": 33.66995566, "pressure": 2.44341267 }, \
#                          "ambient": { "temperature": 21.39450979, "humidity": 26 },\
#                          "timeCreated": "2017-10-27T18:14:02.4911177Z" })

# Normal
test_sample = json.dumps({ "machine": { "temperature": 31.16469009, "pressure": 2.158002669 }, \
                          "ambient": { "temperature": 21.17794693, "humidity": 25 },\
                          "timeCreated": "2017-10-27T18:14:02.4911177Z" })

test_sample = bytes(test_sample,encoding = 'utf8')

prediction = aci_service.run(input_data = test_sample)
print(prediction)
# Out:
# ['{"machine": {"temperature": 31.16469009, "pressure": 2.158002669}, "ambient": {"temperature": 21.17794693, "humidity": 25}, "timeCreated": "2017-10-27T18:14:02.4911177Z", "anomaly": false}']

# %% [markdown]
# ### 4.2: Delete ACI to clean up

# %%
# aci_service.delete()

# %% [markdown]
# ## 5: Deploy container to Azure IoT Edge device
# Create a deployment.json file that contains the modules you want to deploy to the device and the routes.  Then push this file to the IoT Hub, which will then send it to the IoT Edge device.  The IoT Edge agent will then pull the Docker images and run them.

# %%
ws.get_details()
container_reg = image.image_location
reg_name=container_reg.split("/")[-2]
container_url = "\"" + image.image_location + "\","
print(container_reg)
print(reg_name)
print(container_url)
# Out:
# tedwayamliot70d2b646.azurecr.io/tempanomalydetection:1
# tedwayamliot70d2b646.azurecr.io
# "tedwayamliot70d2b646.azurecr.io/tempanomalydetection:1",

# %%
# Getting your container details
container_reg = image.image_location
reg_name=container_reg.split("/")[-2]
reg_name=reg_name.split(".")[-3]
container_url = "\"" + image.image_location + "\","
subscription_id = ws.subscription_id
print('{}'.format(image.image_location))
print('{}'.format(reg_name))
print('{}'.format(subscription_id))
from azure.mgmt.containerregistry import ContainerRegistryManagementClient
from azure.mgmt import containerregistry
client = ContainerRegistryManagementClient(ws._auth,subscription_id)
result= client.registries.list_credentials(resource_group_name, reg_name, custom_headers=None, raw=False)
username = result.username
password = result.passwords[0].value
# Out:
# tedwayamliot70d2b646.azurecr.io/tempanomalydetection:1
# tedwayamliot70d2b646
# 75f78a03-482f-4fd8-8c71-5ddc08f92726

# %%
file = open('iot-workshop-deployment-template.json')
contents = file.read()
contents = contents.replace('__MODULE_NAME', module_name)
contents = contents.replace('__REGISTRY_NAME', reg_name)
contents = contents.replace('__REGISTRY_USER_NAME', username)
contents = contents.replace('__REGISTRY_PASSWORD', password)
contents = contents.replace('__REGISTRY_IMAGE_LOCATION', image.image_location)
with open('./deployment.json', 'wt', encoding='utf-8') as output_file:
    output_file.write(contents)

# %%
# Push the deployment JSON to the IOT Hub
# !az iot edge set-modules --device-id $iot_device_id --hub-name $iot_hub_name --content deployment.json
# Out:
# [
#   {
#     "authenticationType": "sas",
#     "capabilities": {
#       "iotEdge": false
#     },
#     "cloudToDeviceMessageCount": 0,
#     "connectionState": "Connected",
#     "deviceEtag": "NjQ4MTI1NzY=",
#     "deviceId": "iot-edge-device",
#     "etag": "AAAAAAAAAAI=",
#     "lastActivityTime": "0001-01-01T00:00:00+00:00",
#     "moduleId": "$edgeAgent",
#     "properties": {
#       "desired": {
#         "$metadata": {
#           "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#           "$lastUpdatedVersion": 2,
#           "modules": {
#             "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#             "$lastUpdatedVersion": 2,
#             "machinelearningmodule": {
#               "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#               "$lastUpdatedVersion": 2,
#               "restartPolicy": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "settings": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2,
#                 "createOptions": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2
#                 },
#                 "image": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2
#                 }
#               },
#               "status": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "type": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "version": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               }
#             },
#             "tempSensor": {
#               "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#               "$lastUpdatedVersion": 2,
#               "restartPolicy": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "settings": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2,
#                 "createOptions": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2
#                 },
#                 "image": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2
#                 }
#               },
#               "status": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "type": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "version": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               }
#             }
#           },
#           "runtime": {
#             "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#             "$lastUpdatedVersion": 2,
#             "settings": {
#               "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#               "$lastUpdatedVersion": 2,
#               "loggingOptions": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "minDockerVersion": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "registryCredentials": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2,
#                 "tedwayamliot70d2b646": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2,
#                   "address": {
#                     "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                     "$lastUpdatedVersion": 2
#                   },
#                   "password": {
#                     "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                     "$lastUpdatedVersion": 2
#                   },
#                   "username": {
#                     "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                     "$lastUpdatedVersion": 2
#                   }
#                 }
#               }
#             },
#             "type": {
#               "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#               "$lastUpdatedVersion": 2
#             }
#           },
#           "schemaVersion": {
#             "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#             "$lastUpdatedVersion": 2
#           },
#           "systemModules": {
#             "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#             "$lastUpdatedVersion": 2,
#             "edgeAgent": {
#               "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#               "$lastUpdatedVersion": 2,
#               "settings": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2,
#                 "createOptions": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2
#                 },
#                 "env": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2,
#                   "UpstreamProtocol": {
#                     "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                     "$lastUpdatedVersion": 2,
#                     "value": {
#                       "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                       "$lastUpdatedVersion": 2
#                     }
#                   }
#                 },
#                 "image": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2
#                 }
#               },
#               "type": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               }
#             },
#             "edgeHub": {
#               "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#               "$lastUpdatedVersion": 2,
#               "restartPolicy": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "settings": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2,
#                 "createOptions": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2
#                 },
#                 "env": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2,
#                   "UpstreamProtocol": {
#                     "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                     "$lastUpdatedVersion": 2,
#                     "value": {
#                       "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                       "$lastUpdatedVersion": 2
#                     }
#                   }
#                 },
#                 "image": {
#                   "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                   "$lastUpdatedVersion": 2
#                 }
#               },
#               "status": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               },
#               "type": {
#                 "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#                 "$lastUpdatedVersion": 2
#               }
#             }
#           }
#         },
#         "$version": 2,
#         "modules": {
#           "machinelearningmodule": {
#             "restartPolicy": "always",
#             "settings": {
#               "createOptions": "{\"HostConfig\":{\"Binds\":[\"/data/misc/camera:/app/vam_model_folder\"],\"NetworkMode\":\"host\"},\"NetworkingConfig\":{\"EndpointsConfig\":{\"host\":{}}},\"WorkingDir\":\"/var/azureml-app\"}",
#               "image": "tedwayamliot70d2b646.azurecr.io/tempanomalydetection:1"
#             },
#             "status": "running",
#             "type": "docker",
#             "version": "1.0"
#           },
#           "tempSensor": {
#             "restartPolicy": "always",
#             "settings": {
#               "createOptions": "",
#               "image": "mcr.microsoft.com/azureiotedge-simulated-temperature-sensor:1.0"
#             },
#             "status": "running",
#             "type": "docker",
#             "version": "1.0"
#           }
#         },
#         "runtime": {
#           "settings": {
#             "loggingOptions": "",
#             "minDockerVersion": "v1.25",
#             "registryCredentials": {
#               "tedwayamliot70d2b646": {
#                 "address": "tedwayamliot70d2b646.azurecr.io",
#                 "password": "UyOx71NYST6KBmt6jvDQ0gddU53Oo2Y+",
#                 "username": "tedwayamliot70d2b646"
#               }
#             }
#           },
#           "type": "docker"
#         },
#         "schemaVersion": "1.0",
#         "systemModules": {
#           "edgeAgent": {
#             "settings": {
#               "createOptions": "{}",
#               "env": {
#                 "UpstreamProtocol": {
#                   "value": "MQTT"
#                 }
#               },
#               "image": "mcr.microsoft.com/azureiotedge-agent:1.0"
#             },
#             "type": "docker"
#           },
#           "edgeHub": {
#             "restartPolicy": "always",
#             "settings": {
#               "createOptions": "{\"User\":\"root\",\"HostConfig\":{\"PortBindings\":{\"5671/tcp\":[{\"HostPort\":\"5671\"}], \"8883/tcp\":[{\"HostPort\":\"8883\"}],\"443/tcp\":[{\"HostPort\":\"443\"}]}}}",
#               "env": {
#                 "UpstreamProtocol": {
#                   "value": "MQTT "
#                 }
#               },
#               "image": "mcr.microsoft.com/azureiotedge-hub:1.0"
#             },
#             "status": "running",
#             "type": "docker"
#           }
#         }
#       },
#       "reported": {
#         "$metadata": {
#           "$lastUpdated": "2019-05-20T14:36:41.801148Z",
#           "lastDesiredStatus": {
#             "$lastUpdated": "2019-05-20T14:36:41.801148Z",
#             "code": {
#               "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#             },
#             "description": {
#               "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#             }
#           },
#           "runtime": {
#             "$lastUpdated": "2019-05-20T14:36:41.801148Z",
#             "Type": {
#               "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#             },
#             "platform": {
#               "$lastUpdated": "2019-05-20T14:36:41.801148Z",
#               "architecture": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#               },
#               "os": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#               },
#               "version": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#               }
#             }
#           },
#           "schemaVersion": {
#             "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#           },
#           "systemModules": {
#             "$lastUpdated": "2019-05-20T14:36:41.801148Z",
#             "edgeAgent": {
#               "$lastUpdated": "2019-05-20T14:36:41.801148Z",
#               "exitCode": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#               },
#               "lastExitTimeUtc": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#               },
#               "lastStartTimeUtc": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#               },
#               "runtimeStatus": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#               },
#               "settings": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z",
#                 "createOptions": {
#                   "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#                 },
#                 "image": {
#                   "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#                 },
#                 "imageHash": {
#                   "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#                 }
#               },
#               "statusDescription": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#               },
#               "type": {
#                 "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#               }
#             }
#           },
#           "version": {
#             "$lastUpdated": "2019-05-20T14:36:41.801148Z",
#             "build": {
#               "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#             },
#             "commit": {
#               "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#             },
#             "version": {
#               "$lastUpdated": "2019-05-20T14:36:41.801148Z"
#             }
#           }
#         },
#         "$version": 2,
#         "lastDesiredStatus": {
#           "code": 417,
#           "description": "This device has an empty configuration for the edge agent. Please set a deployment manifest."
#         },
#         "runtime": {
#           "Type": "Unknown",
#           "platform": {
#             "architecture": "x86_64",
#             "os": "linux",
#             "version": "1.0.7 (f455ae2cd66db716c4bd8e7aaa7984ce092481c0)"
#           }
#         },
#         "schemaVersion": "1.0",
#         "systemModules": {
#           "edgeAgent": {
#             "exitCode": 0,
#             "lastExitTimeUtc": "0001-01-01T00:00:00.0000000Z",
#             "lastStartTimeUtc": "2019-05-20T14:36:36.5759571Z",
#             "runtimeStatus": "running",
#             "settings": {
#               "createOptions": "{}",
#               "image": "mcr.microsoft.com/azureiotedge-agent:1.0",
#               "imageHash": "sha256:219c2aff4adcca7d9898aad91ff29f0c22eb4ca96a1839e7434591cd459a8c73"
#             },
#             "statusDescription": "running",
#             "type": "docker"
#           }
#         },
#         "version": {
#           "build": "21905529",
#           "commit": "f455ae2cd66db716c4bd8e7aaa7984ce092481c0",
#           "version": "1.0.7"
#         }
#       }
#     },
#     "status": "enabled",
#     "statusUpdateTime": "0001-01-01T00:00:00+00:00",
#     "version": 4,
#     "x509Thumbprint": {
#       "primaryThumbprint": null,
#       "secondaryThumbprint": null
#     }
#   },
#   {
#     "authenticationType": "none",
#     "capabilities": {
#       "iotEdge": false
#     },
#     "cloudToDeviceMessageCount": 0,
#     "connectionState": "Disconnected",
#     "deviceEtag": "NjQ4MTI1NzU=",
#     "deviceId": "iot-edge-device",
#     "etag": "AAAAAAAAAAI=",
#     "lastActivityTime": "0001-01-01T00:00:00+00:00",
#     "moduleId": "$edgeHub",
#     "properties": {
#       "desired": {
#         "$metadata": {
#           "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#           "$lastUpdatedVersion": 2,
#           "routes": {
#             "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#             "$lastUpdatedVersion": 2,
#             "machineLearningToIoTHub": {
#               "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#               "$lastUpdatedVersion": 2
#             },
#             "sensorToMachineLearning": {
#               "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#               "$lastUpdatedVersion": 2
#             }
#           },
#           "schemaVersion": {
#             "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#             "$lastUpdatedVersion": 2
#           },
#           "storeAndForwardConfiguration": {
#             "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#             "$lastUpdatedVersion": 2,
#             "timeToLiveSecs": {
#               "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#               "$lastUpdatedVersion": 2
#             }
#           }
#         },
#         "$version": 2,
#         "routes": {
#           "machineLearningToIoTHub": "FROM /messages/modules/machinelearningmodule/outputs/amlOutput INTO $upstream",
#           "sensorToMachineLearning": "FROM /messages/modules/tempSensor/outputs/temperatureOutput INTO BrokeredEndpoint(\"/modules/machinelearningmodule/inputs/amlInput\")"
#         },
#         "schemaVersion": "1.0",
#         "storeAndForwardConfiguration": {
#           "timeToLiveSecs": 7200
#         }
#       },
#       "reported": {
#         "$metadata": {
#           "$lastUpdated": "0001-01-01T00:00:00Z"
#         },
#         "$version": 1
#       }
#     },
#     "status": "enabled",
#     "statusUpdateTime": "0001-01-01T00:00:00+00:00",
#     "version": 3,
#     "x509Thumbprint": {
#       "primaryThumbprint": null,
#       "secondaryThumbprint": null
#     }
#   },
#   {
#     "authenticationType": "none",
#     "capabilities": {
#       "iotEdge": false
#     },
#     "cloudToDeviceMessageCount": 0,
#     "connectionState": "Disconnected",
#     "deviceEtag": "ODA4MTIxNDE=",
#     "deviceId": "iot-edge-device",
#     "etag": "AAAAAAAAAAE=",
#     "lastActivityTime": "0001-01-01T00:00:00",
#     "moduleId": "machinelearningmodule",
#     "properties": {
#       "desired": {
#         "$metadata": {
#           "$lastUpdated": "2019-05-20T15:01:02.6933933Z",
#           "$lastUpdatedVersion": 1
#         },
#         "$version": 1
#       },
#       "reported": {
#         "$metadata": {
#           "$lastUpdated": "2019-05-20T15:01:02.6933933Z",
#           "$lastUpdatedVersion": 1
#         },
#         "$version": 1
#       }
#     },
#     "status": "enabled",
#     "statusUpdateTime": "0001-01-01T00:00:00",
#     "version": 2,
#     "x509Thumbprint": {
#       "primaryThumbprint": null,
#       "secondaryThumbprint": null
#     }
#   },
#   {
#     "authenticationType": "none",
#     "capabilities": {
#       "iotEdge": false
#     },
#     "cloudToDeviceMessageCount": 0,
#     "connectionState": "Disconnected",
#     "deviceEtag": "Mzg0MDI2MDM2",
#     "deviceId": "iot-edge-device",
#     "etag": "AAAAAAAAAAE=",
#     "lastActivityTime": "0001-01-01T00:00:00",
#     "moduleId": "tempSensor",
#     "properties": {
#       "desired": {
#         "$metadata": {
#           "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#           "$lastUpdatedVersion": 1
#         },
#         "$version": 1
#       },
#       "reported": {
#         "$metadata": {
#           "$lastUpdated": "2019-05-20T15:01:02.6621492Z",
#           "$lastUpdatedVersion": 1
#         },
#         "$version": 1
#       }
#     },
#     "status": "enabled",
#     "statusUpdateTime": "0001-01-01T00:00:00",
#     "version": 2,
#     "x509Thumbprint": {
#       "primaryThumbprint": null,
#       "secondaryThumbprint": null
#     }
#   }
# ]

# %% [markdown]
# ## Congratulations!
# You made it to the end of the tutorial!  You can monitor messages from your edge device to your IoT Hub with VS Code and the [Azure IoT Hub Toolkit](https://marketplace.visualstudio.com/items?itemName=vsciot-vscode.azure-iot-toolkit) extension.
